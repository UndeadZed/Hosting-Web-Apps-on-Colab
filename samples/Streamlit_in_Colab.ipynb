# %% [markdown]
# # Example for running Streamlit webAPP in Colab

# %% [markdown]
# ## Step 1: install essential libraries

# %%
# !pip install streamlit==1.25.0
# !pip install streamlit
# !pip install yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 38.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 50.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Step 2: Make the apppy file which uses streamlit

# %%
# %%writefile app.py

import streamlit as st
import yfinance as yf
import pandas as pd


st.write("""
# Simple stock prices app:

shown here are the stock prices and volume of Google

 """)


tickerSymbol = "GOOGL"
tickerData = yf.Ticker(tickerSymbol)
tickerdf = tickerData.history(period="1d", start="2010-5-31" , end="2022-5-31")


st.line_chart(tickerdf.Close)
st.line_chart(tickerdf.Volume)
# Out:
# Writing app.py

# %% [markdown]
# ## Step 3: Use npm ngrok to host the streamlit APP

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
# Getting the Global IP of the notebook so we can access the app
# !curl ipv4.icanhazip.com
# Out:
# 34.90.110.46

# %%
ngrok_token = "<YOUR_AUTH_TOKEN>"

# %%
# !npm install -g ngrok
# !ngrok config add-authtoken {ngrok_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼
# added 44 packages in 7s
# ⠼
# ⠼9 packages are looking for funding
# ⠼  run `npm fund` for details
# ⠼Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !ngrok http 8501 --log=stdout
# Out:
# INFO[12-19|19:06:33] no configuration paths supplied
# INFO[12-19|19:06:33] using configuration at default config path path=/root/.config/ngrok/ngrok.yml
# INFO[12-19|19:06:33] open config file                         path=/root/.config/ngrok/ngrok.yml err=nil
# t=2024-12-19T19:06:33+0000 lvl=info msg="starting web service" obj=web addr=127.0.0.1:4040 allow_hosts=[]
# t=2024-12-19T19:06:33+0000 lvl=info msg="client session established" obj=tunnels.session
# t=2024-12-19T19:06:33+0000 lvl=info msg="tunnel session started" obj=tunnels.session
# t=2024-12-19T19:06:33+0000 lvl=info msg="started tunnel" obj=tunnels name=command_line addr=http://localhost:8501 url=https://cbc7-34-90-110-46.ngrok-free.app
# t=2024-12-19T19:06:42+0000 lvl=info msg="join connections" obj=join id=940936d57107 l=127.0.0.1:8501 r=102.184.178.250:50593
# t=2024-12-19T19:06:42+0000 lvl=info msg="join connections" obj=join id=9e5f9bd41ce2 l=127.0.0.1:8501 r=102.184.178.250:50593
# ...

# %% [markdown]
# # Done, Now this is what you're supposed to see:
#
# ![Screenshot 2023-11-18 230518.png](data:image/png;base64,...)

# %% [markdown]
# # Old Method using Localtunnel

# %%
# !npx localtunnel --port 8501 --subdomain streamlit12e4sad1
