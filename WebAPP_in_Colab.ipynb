# %% [markdown]
# # Example for Running a normal Web APP in Colab

# %% [markdown]
# ## Step 1: Add your Website in ths case I'll just clone a repo from this amazing developer [FahimFBA](https://github.com/FahimFBA)

# %%
# !git clone https://github.com/FahimFBA/RainyRoof_Restaurant_Website
# Out:
# Cloning into 'RainyRoof_Restaurant_Website'...
# remote: Enumerating objects: 1716, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 1716 (delta 51), reused 47 (delta 47), pack-reused 1617 (from 1)
# Receiving objects: 100% (1716/1716), 25.59 MiB | 21.94 MiB/s, done.
# Resolving deltas: 100% (479/479), done.

# %%
# %cd /content/RainyRoof_Restaurant_Website
# Out:
# /content/RainyRoof_Restaurant_Website

# %% [markdown]
# ## Step 2: make sure the default page file for your project in this case index.html is in your current directory

# %%
# making sure index.html is here
# !ls
# Out:
# CODE_OF_CONDUCT.md  debug.log	 img	     LICENSE	resources
# CONTRIBUTING.md     desktop.ini  index.html  README.md	vendors

# %%
# !npm --version
# Out:
# 10.8.2

# %% [markdown]
# ## Step 3: Now we use NPM http-server and localtunnel to host the webapp

# %%
# !npm install -g concurrently
# !npm install -g ngrok
# !npm install --global http-server
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴
# added 26 packages in 7s
# ⠴
# ⠴6 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸
# added 44 packages in 7s
# ⠸
# ⠸9 packages are looking for funding
# ⠸  run `npm fund` for details
# ⠸⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸
# added 49 packages in 4s
# ⠸
# ⠸15 packages are looking for funding
# ⠸  run `npm fund` for details
# ⠸

# %%
ngrok_token = "<YOUR_AUTH_TOKEN>"
# !ngrok config add-authtoken {ngrok_token}
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# Getting the Global IP of the notebook so we can access the app
# !curl ipv4.icanhazip.com
# Out:
# 35.199.180.255

# %%
# !concurrently "http-server -p 8501" "ngrok http 8501 --log=stdout"
# Out:
# [1] t=2024-12-19T18:06:52+0000 lvl=info msg="no configuration paths supplied"
# [1] t=2024-12-19T18:06:52+0000 lvl=info msg="using configuration at default config path" path=/root/.config/ngrok/ngrok.yml
# [1] t=2024-12-19T18:06:52+0000 lvl=info msg="open config file" path=/root/.config/ngrok/ngrok.yml err=nil
# [1] t=2024-12-19T18:06:53+0000 lvl=info msg="starting web service" obj=web addr=127.0.0.1:4040 allow_hosts=[]
# [1] t=2024-12-19T18:06:53+0000 lvl=info msg="client session established" obj=tunnels.session
# [1] t=2024-12-19T18:06:53+0000 lvl=info msg="tunnel session started" obj=tunnels.session
# [1] t=2024-12-19T18:06:53+0000 lvl=info msg="started tunnel" obj=tunnels name=command_line addr=http://localhost:8501 url=https://52af-35-199-180-255.ngrok-free.app
# [0] Starting up http-server, serving ./
# [0]
# [0] http-server version: 14.1.1
# [0]
# [0] http-server settings:
# [0] CORS: disabled
# [0] Cache: 3600 seconds
# [0] Connection Timeout: 120 seconds
# ...

# %% [markdown]
# # Done now this should be what you see:
#
# ![Screenshot 2023-11-18 224517.png](data:image/png;base64,...)

# %% [markdown]
# # Old Method using Localtunnel

# %%
# !npm install --global localtunnel

# %%
# !concurrently "http-server ./ -p 8501" '''lt -h "http://localtunnel.me" --port 8501 --subdomain example18736'''
# Out:
# [0] Starting up http-server, serving ./
# [0]
# [0] http-server version: 14.1.1
# [0]
# [0] http-server settings:
# [0] CORS: disabled
# [0] Cache: 3600 seconds
# [0] Connection Timeout: 120 seconds
# [0] Directory Listings: visible
# [0] AutoIndex: visible
# [0] Serve GZIP Files: false
# [0] Serve Brotli Files: false
# [0] Default File Extension: none
# [0]
# [0] Available on:
# [0]   http://127.0.0.1:8501
# [0]   http://172.28.0.12:8501
# [0] Hit CTRL-C to stop the server
# [0]
# [1] your url is: https://example18736.loca.lt
# [0] http-server stopped.
# [1] lt -h "http://localtunnel.me" --port 8507 --subdomain example18736 exited with code SIGINT
# [0] http-server ./ -p 8501 exited with code SIGINT
